# %%
import numpy as np
import matplotlib.pyplot as plt

R_2m = 2

# Определение массива углов
theta_degrees = np.arange(-90, 100, 10)
massive_theta_degrees = np.array(theta_degrees)
theta_radians = np.radians(massive_theta_degrees)

# Вычисление значений b и c
b_2m = abs(np.sin(theta_radians) * R_2m)
c_2m = abs(np.cos(theta_radians) * R_2m)


# Печать значений b с индексами
print("Ниже указаны b(угол), с(угол), при R = 2м")

for index, b in enumerate(b_2m):
    b = round(b, 2)
    print(f"b{theta_degrees[index]} = {b}")

# Печать значений c с индексами
for index, c in enumerate(c_2m):
    c = round(c, 2)
    print(f"c{theta_degrees[index]} = {c}")



# https://sky.pro/wiki/python/ponimaem-funktsiyu-enumerate-v-python-na-primere-koda/
# https://sky.pro/wiki/python/

M_03 = [86.691,
59.815,
37.265,
52.362,
52.250,
33.567,
28.924,
19.854,
9.997,
0.802,
-14.291,
-32.475,
-54.203,
-55.313,
-54.861,
-52.250,
-54.722,
-70.84,
-74.123,   
]

M_06 = [72.569,
44.730,
22.033,
17.806,
68.361,
27.885,
24.104,
16.777,
8.226,
-5.941,
-15.375,
-22.417,
-37.578,
-50.526,
-54.405,
-65.983,
-85.164,
-28.909,
-87.806,
]

M_03_reverse = M_03[::-1]
M_06_reverse = M_06[::-1]

plt.figure(figsize=(8, 4), dpi=120)
plt.plot(theta_degrees, M_03_reverse, label='L = 0.3m', color='blue', linestyle='--')
plt.plot(theta_degrees, M_06_reverse, label='L = 0.6m', color='green', linestyle=':')

plt.scatter(theta_degrees, M_03_reverse, color='blue', s = 20)
plt.scatter(theta_degrees, M_06_reverse, color='green', s = 20)

plt.xticks(np.arange(min(theta_degrees), max(theta_degrees)+1, 10))
plt.yticks(np.arange(-90, 100, 10))
plt.title(r"$AOmin = 2m$")
plt.xlabel(r'$(\theta), град$')
plt.ylabel(r'$M(\theta)$')
plt.legend(loc='upper center', prop={'size': 10})
plt.grid(True)
plt.show()
# Out:
# Ниже указаны b(угол), с(угол), при R = 2м
# b-90 = 2.0
# b-80 = 1.97
# b-70 = 1.88
# b-60 = 1.73
# b-50 = 1.53
# b-40 = 1.29
# b-30 = 1.0
# b-20 = 0.68
# b-10 = 0.35
# b0 = 0.0
# b10 = 0.35
# b20 = 0.68
# b30 = 1.0
# b40 = 1.29
# b50 = 1.53
# b60 = 1.73
# b70 = 1.88
# b80 = 1.97
# b90 = 2.0
# c-90 = 0.0
# c-80 = 0.35
# c-70 = 0.68
# c-60 = 1.0
# c-50 = 1.29
# c-40 = 1.53
# c-30 = 1.73
# c-20 = 1.88
# c-10 = 1.97
# c0 = 2.0
# c10 = 1.97
# c20 = 1.88
# c30 = 1.73
# c40 = 1.53
# c50 = 1.29
# c60 = 1.0
# c70 = 0.68
# c80 = 0.35
# c90 = 0.0

# %%
SKO_03 = [8.328,
13.901,
7.947,
12.925,
11.064,
8.116,
8.076,
7.590,
7.267,
8.505,
7.697,
7.215,
11.904,
10.524,
13.319,
11.064,
13.571,
22.555,
14.844,
]

SKO_06 = [12.377,
5.679,
2.186,
4.288,
10.324,
4.089,
3.220,
2.859,
2.765,
3.699,
2.683,
5.079,
4.135,
5.028,
5.977,
8.843,
8.056,
1.543,
5.719,
]



plt.figure(figsize=(8, 4), dpi=120)
plt.plot(theta_degrees, SKO_03[::-1], label='L = 0.3m', color='blue', linestyle='--')
plt.plot(theta_degrees, SKO_06[::-1], label='L = 0.6m', color='green', linestyle=':')

plt.scatter(theta_degrees, SKO_03[::-1], color='blue', s = 20)
plt.scatter(theta_degrees, SKO_06[::-1], color='green', s = 20)

plt.xticks(np.arange(min(theta_degrees), max(theta_degrees)+1, 10))
plt.yticks(np.arange(0, 24, 2))
plt.title(r"$AOmin = 2m$")
plt.xlabel(r'$(\theta), град$')
plt.ylabel(r'$СКО$')
plt.legend(loc='upper center', prop={'size': 10})
plt.grid(True)
plt.show()

# %%
theta_degrees = [-90, -80, -60, -40, -20, 0, 20, 40, 60, 80, 90]
massive_theta_degrees = np.array(theta_degrees)
theta_radians = np.radians(massive_theta_degrees)

R_4_7m = 4.7

b_4_7m = abs(np.sin(theta_radians) * R_4_7m)
c_4_7m = abs(np.cos(theta_radians) * R_4_7m)

print("____________________________________________________________________\n")
print("Ниже указаны b(угол), с(угол), при R = 4.7м")
# Печать значений b с индексами
for index, b in enumerate(b_4_7m):
    b = round(b, 2)
    print(f"b{theta_degrees[index]} = {b}")

# Печать значений c с индексами
for index, c in enumerate(c_4_7m):
    c = round(c, 2)
    print(f"c{theta_degrees[index]} = {c}")

M_03 = [68.663,
39.348,
45.242,
-1.161,
-34.971,
-13.675,
-48.308,
-57.527,
-73.279,
-77.769,
-52.783,
]

M_06 = [65.527,
56.895,
53.538,
32.689,
12.543,
-4.786,
-26.426,
-47.186,
-86.892,
-89.603,
-83.680,
]

M_03_reverse = M_03[::-1]
M_06_reverse = M_06[::-1]

plt.figure(figsize=(8, 4), dpi=120)
plt.plot(theta_degrees, M_03_reverse, label='L = 0.3m', color='blue', linestyle='--')
plt.plot(theta_degrees, M_06_reverse, label='L = 0.6m', color='green', linestyle=':')

plt.scatter(theta_degrees, M_03_reverse, color='blue', s = 20)
plt.scatter(theta_degrees, M_06_reverse, color='green', s = 20)

plt.xticks(np.arange(min(theta_degrees), max(theta_degrees)+1, 10))
plt.yticks(np.arange(-90, 100, 10))
plt.title(r"$AOmin = 4.7m$")
plt.xlabel(r'$(\theta), град$')
plt.ylabel(r'$M(\theta)$')
plt.legend(loc='upper center', prop={'size': 10})
plt.grid(True)
plt.show()
# Out:
# ____________________________________________________________________
#
# Ниже указаны b(угол), с(угол), при R = 4.7м
# b-90 = 4.7
# b-80 = 4.63
# b-60 = 4.07
# b-40 = 3.02
# b-20 = 1.61
# b0 = 0.0
# b20 = 1.61
# b40 = 3.02
# b60 = 4.07
# b80 = 4.63
# b90 = 4.7
# c-90 = 0.0
# c-80 = 0.82
# c-60 = 2.35
# c-40 = 3.6
# c-20 = 4.42
# c0 = 4.7
# c20 = 4.42
# c40 = 3.6
# c60 = 2.35
# c80 = 0.82
# c90 = 0.0

# %%
SKO_03 = [17.799,
7.818,
11.349,
6.076,
10.262,
13.019,
6.956,
14.591,
13.886,
13.787,
9.021,
]

SKO_06 = [6.144,
4.447,
5.279,
3.445,
5.538,
4.067,
3.497,
4.932,
5.348,
2.310,
8.574,
]

plt.figure(figsize=(8, 4), dpi=120)
plt.plot(theta_degrees, SKO_03[::-1], label='L = 0.3m', color='blue', linestyle='--')
plt.plot(theta_degrees, SKO_06[::-1], label='L = 0.6m', color='green', linestyle=':')

plt.scatter(theta_degrees, SKO_03[::-1], color='blue', s = 20)
plt.scatter(theta_degrees, SKO_06[::-1], color='green', s = 20)

plt.xticks(np.arange(min(theta_degrees), max(theta_degrees)+1, 10))
plt.yticks(np.arange(0, 20, 2))
plt.title(r"$AOmin = 4.7m$")
plt.xlabel(r'$(\theta), град$')
plt.ylabel(r'$СКО$')
plt.legend(loc='upper center', prop={'size': 10})
plt.grid(True)
plt.show()

# %%
theta_degrees_2m = np.arange(-90, 100, 10)
theta_degrees_4_7m = [-90, -80, -60, -40, -20, 0, 20, 40, 60, 80, 90]

M_03_2m = [86.691,
59.815,
37.265,
52.362,
52.250,
33.567,
28.924,
19.854,
9.997,
0.802,
-14.291,
-32.475,
-54.203,
-55.313,
-54.861,
-52.250,
-54.722,
-70.84,
-74.123,   
]

M_06_2m = [72.569,
44.730,
22.033,
17.806,
68.361,
27.885,
24.104,
16.777,
8.226,
-5.941,
-15.375,
-22.417,
-37.578,
-50.526,
-54.405,
-65.983,
-85.164,
-28.909,
-87.806,
]

M_03_4_7m = [68.663,
39.348,
45.242,
-1.161,
-34.971,
-13.675,
-48.308,
-57.527,
-73.279,
-77.769,
-52.783,
]

M_06_4_7m = [65.527,
56.895,
53.538,
32.689,
12.543,
-4.786,
-26.426,
-47.186,
-86.892,
-89.603,
-83.680,
]

plt.figure(figsize=(10, 6), dpi=120)
plt.plot(theta_degrees_2m, M_03_2m[::-1], label='L = 0.3m, AOmin = 2m', color='blue', linestyle='--')
plt.plot(theta_degrees_2m, M_06_2m[::-1], label='L = 0.6m, AOmin = 2m', color='green', linestyle=':')
plt.plot(theta_degrees_4_7m, M_03_4_7m[::-1], label='L = 0.3m, AOmin = 4.7m', color='red', linestyle='-')
plt.plot(theta_degrees_4_7m, M_06_4_7m[::-1], label='L = 0.6m, AOmin = 4.7m', color='orange', linestyle='-.')

plt.scatter(theta_degrees_2m, M_03_2m[::-1], color='blue', s = 20)
plt.scatter(theta_degrees_2m, M_06_2m[::-1], color='green', s = 20)
plt.scatter(theta_degrees_4_7m, M_03_4_7m[::-1], color='red', s = 20)
plt.scatter(theta_degrees_4_7m, M_06_4_7m[::-1], color='orange', s = 20)

plt.xticks(np.arange(min(theta_degrees_2m), max(theta_degrees_2m)+1, 10))
plt.yticks(np.arange(-90, 100, 10))
plt.xlabel(r'$(\theta), град$')
plt.ylabel(r'$M(\theta)$')
plt.legend(loc='upper left', prop={'size': 10})
plt.grid(True)
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt

theta_degrees_2m = np.arange(-90, 100, 10)
theta_degrees_4_7m = [-90, -80, -60, -40, -20, 0, 20, 40, 60, 80, 90]

M_03_2m = [86.691, 59.815, 37.265, 52.362, 52.250, 33.567, 28.924, 19.854, 9.997, 0.802, -14.291, -32.475, -54.203, -55.313, -54.861, -52.250, -54.722, -70.84, -74.123]
M_06_2m = [72.569, 44.730, 22.033, 17.806, 68.361, 27.885, 24.104, 16.777, 8.226, -5.941, -15.375, -22.417, -37.578, -50.526, -54.405, -65.983, -85.164, -28.909, -87.806]
M_03_4_7m = [68.663, 39.348, 45.242, -1.161, -34.971, -13.675, -48.308, -57.527, -73.279, -77.769, -52.783]
M_06_4_7m = [65.527, 56.895, 53.538, 32.689, 12.543, -4.786, -26.426, -47.186, -86.892, -89.603, -83.680]

# Создаем график с исходными данными
plt.figure(figsize=(10, 6), dpi=120)

# Апроксимация и линии для L = 0.3m, AOmin = 2m
coeffs_03_2m = np.polyfit(theta_degrees_2m, M_03_2m[::-1], 1)
y_fit_03_2m = np.polyval(coeffs_03_2m, theta_degrees_2m)
#plt.plot(sin_theta_degrees_2m, M_03_2m[::-1], label='L = 0.3m, AOmin = 2m', color='blue', linestyle='--')
plt.plot(theta_degrees_2m, y_fit_03_2m, color='blue', linestyle='-', label='L = 0.3m, AOmin = 2m (linear fit)')

# Апроксимация и линии для L = 0.6m, AOmin = 2m
coeffs_06_2m = np.polyfit(theta_degrees_2m, M_06_2m[::-1], 1)
y_fit_06_2m = np.polyval(coeffs_06_2m, theta_degrees_2m)
#plt.plot(sin_theta_degrees_2m, M_06_2m[::-1], label='L = 0.6m, AOmin = 2m', color='green', linestyle=':')
plt.plot(theta_degrees_2m, y_fit_06_2m, color='green', linestyle='-.', label='L = 0.6m, AOmin = 2m (linear fit)')

# Апроксимация и линии для L = 0.3m, AOmin = 4.7m
coeffs_03_4_7m = np.polyfit(theta_degrees_4_7m, M_03_4_7m[::-1], 1)
y_fit_03_4_7m = np.polyval(coeffs_03_4_7m, theta_degrees_4_7m)
#plt.plot(sin_theta_degrees_4_7m, M_03_4_7m[::-1], label='L = 0.3m, AOmin = 4.7m', color='red', linestyle='-')
plt.plot(theta_degrees_4_7m, y_fit_03_4_7m, color='red', linestyle='--', label='L = 0.3m, AOmin = 4.7m (linear fit)')

# Апроксимация и линии для L = 0.6m, AOmin = 4.7m
coeffs_06_4_7m = np.polyfit(theta_degrees_4_7m, M_06_4_7m[::-1], 1)
y_fit_06_4_7m = np.polyval(coeffs_06_4_7m, theta_degrees_4_7m)
#plt.plot(sin_theta_degrees_4_7m, M_06_4_7m[::-1], label='L = 0.6m, AOmin = 4.7m', color='orange', linestyle='-.')
plt.plot(theta_degrees_4_7m, y_fit_06_4_7m, color='orange', linestyle=':', label='L = 0.6m, AOmin = 4.7m (linear fit)')

# Разметка точек
#plt.scatter(sin_theta_degrees_2m, M_03_2m[::-1], color='blue', s=20)
#plt.scatter(sin_theta_degrees_2m, M_06_2m[::-1], color='green', s=20)
#plt.scatter(sin_theta_degrees_4_7m, M_03_4_7m[::-1], color='red', s=20)
#plt.scatter(sin_theta_degrees_4_7m, M_06_4_7m[::-1], color='orange', s=20)

# Настройки графика
plt.xticks(np.arange(min(theta_degrees_2m), max(theta_degrees_2m) + 1, 10))
plt.yticks(np.arange(-90, 100, 10))
plt.xlabel(r'$(\theta), град$')
plt.ylabel(r'$M(\theta)$')
plt.legend(loc='upper left', prop={'size': 10})
plt.grid(True)
plt.show()

# %%
SKO_03_2m = [8.328,
13.901,
7.947,
12.925,
11.064,
8.116,
8.076,
7.590,
7.267,
8.505,
7.697,
7.215,
11.904,
10.524,
13.319,
11.064,
13.571,
22.555,
14.844,
]

SKO_06_2m = [12.377,
5.679,
2.186,
4.288,
10.324,
4.089,
3.220,
2.859,
2.765,
3.699,
2.683,
5.079,
4.135,
5.028,
5.977,
8.843,
8.056,
1.543,
5.719,
]

SKO_03_4_7m = [17.799,
7.818,
11.349,
6.076,
10.262,
13.019,
6.956,
14.591,
13.886,
13.787,
9.021,
]

SKO_06_4_7m = [6.144,
4.447,
5.279,
3.445,
5.538,
4.067,
3.497,
4.932,
5.348,
2.310,
8.574,
]


plt.figure(figsize=(10, 6), dpi=120)
plt.plot(theta_degrees_2m, SKO_03_2m[::-1], label='L = 0.3m, AOmin = 2m', color='blue', linestyle='--')
plt.plot(theta_degrees_2m, SKO_06_2m[::-1], label='L = 0.6m, AOmin = 2m', color='green', linestyle=':')
plt.plot(theta_degrees_4_7m, SKO_03_4_7m[::-1], label='L = 0.3m, AOmin = 4.7m', color='red', linestyle='-')
plt.plot(theta_degrees_4_7m, SKO_06_4_7m[::-1], label='L = 0.6m, AOmin = 4.7m', color='orange', linestyle='-.')

plt.scatter(theta_degrees_2m, SKO_03_2m[::-1], color='blue', s = 20)
plt.scatter(theta_degrees_2m, SKO_06_2m[::-1], color='green', s = 20)
plt.scatter(theta_degrees_4_7m, SKO_03_4_7m[::-1], color='red', s = 20)
plt.scatter(theta_degrees_4_7m, SKO_06_4_7m[::-1], color='orange', s = 20)

plt.xticks(np.arange(min(theta_degrees_2m), max(theta_degrees_2m)+1, 10))
plt.yticks(np.arange(0, 24, 2))
##plt.title(r"$AOmin = 4.7m$")
plt.xlabel(r'$(\theta), град$')
plt.ylabel(r'$СКО$')
plt.legend(loc='upper center', prop={'size': 10})
plt.grid(True)
plt.show()

# %% [markdown]
# ### Домашнее задание

# %%
theta_degrees = np.arange(-180, 190, 10)
massive_theta_degrees = np.array(theta_degrees)
theta_radians = np.radians(massive_theta_degrees)  # Используем np.radians

AO_min_1m = 1
AO_max_4m = 4

L_03m = 0.3 ## базы АР
L_06m = 0.6

b_1m = np.sin(theta_radians)*AO_min_1m
b_4m = np.sin(theta_radians)*AO_max_4m

c_1m = np.cos(theta_radians)*AO_min_1m
c_4m = np.cos(theta_radians)*AO_max_4m

#theta_evaluation_1 (AO_min_1m, L_03m)
#theta_evaluation_2 (AO_min_1m, L_06m)
#theta_evaluation_3 (AO_min_4m, L_03m)
#theta_evaluation_4 (AO_min_4m, L_06m)

theta_evaluation_1 = np.degrees(np.arcsin( (np.sqrt(c_1m**2 + (b_1m + (L_03m/2))**2) - np.sqrt(c_1m**2 + (b_1m - (L_03m/2))**2) ) / L_03m ))
theta_evaluation_2 = np.degrees(np.arcsin( (np.sqrt(c_1m**2 + (b_1m + (L_06m/2))**2) - np.sqrt(c_1m**2 + (b_1m - (L_06m/2))**2) ) / L_06m ))
theta_evaluation_3 = np.degrees(np.arcsin( (np.sqrt(c_4m**2 + (b_4m + (L_03m/2))**2) - np.sqrt(c_4m**2 + (b_4m - (L_03m/2))**2) ) / L_03m ))
theta_evaluation_4 = np.degrees(np.arcsin( (np.sqrt(c_4m**2 + (b_4m + (L_06m/2))**2) - np.sqrt(c_4m**2 + (b_4m - (L_06m/2))**2) ) / L_06m ))

plt.plot(theta_degrees, theta_evaluation_1, label=f'L = {L_03m}, AOmin = {AO_min_1m}', color='blue', linestyle='--')
plt.plot(theta_degrees, theta_evaluation_2, label=f'L = {L_06m}, AOmin = {AO_min_1m}', color='green', linestyle=':')
plt.plot(theta_degrees, theta_evaluation_3, label=f'L = {L_03m}, AOmax = {AO_max_4m}', color='red', linestyle='-')
plt.plot(theta_degrees, theta_evaluation_4, label=f'L = {L_06m}, AOmax = {AO_max_4m}', color='orange', linestyle='-.')


plt.xticks(np.arange(min(theta_degrees), max(theta_degrees)+1, 30))

plt.yticks(np.arange(-90, 100, 10))

plt.xlabel(r'$(\theta), град$')
plt.ylabel(r'$Оценка(\theta), град$')
plt.legend(loc='upper left', prop={'size': 10})
plt.grid(True)
plt.show()
# Out:
# C:\Users\User\AppData\Local\Temp\ipykernel_14824\4257147362.py:23: RuntimeWarning: invalid value encountered in arcsin
#   theta_evaluation_2 = np.degrees(np.arcsin( (np.sqrt(c_1m**2 + (b_1m + (L_06m/2))**2) - np.sqrt(c_1m**2 + (b_1m - (L_06m/2))**2) ) / L_06m ))
# C:\Users\User\AppData\Local\Temp\ipykernel_14824\4257147362.py:24: RuntimeWarning: invalid value encountered in arcsin
#   theta_evaluation_3 = np.degrees(np.arcsin( (np.sqrt(c_4m**2 + (b_4m + (L_03m/2))**2) - np.sqrt(c_4m**2 + (b_4m - (L_03m/2))**2) ) / L_03m ))

# %%
AO_min_1m = 50
AO_max_4m = 150

L_03m = 150 ## базы АР
L_06m = 1000

b_1m = np.sin(theta_radians)*AO_min_1m
b_4m = np.sin(theta_radians)*AO_max_4m

c_1m = np.cos(theta_radians)*AO_min_1m
c_4m = np.cos(theta_radians)*AO_max_4m

#theta_evaluation_1 (AO_min_1m, L_03m)
#theta_evaluation_2 (AO_min_1m, L_06m)
#theta_evaluation_3 (AO_min_4m, L_03m)
#theta_evaluation_4 (AO_min_4m, L_06m)

theta_evaluation_1 = np.degrees(np.arcsin( (np.sqrt(c_1m**2 + (b_1m + (L_03m/2))**2) - np.sqrt(c_1m**2 + (b_1m - (L_03m/2))**2) ) / L_03m ))
theta_evaluation_2 = np.degrees(np.arcsin( (np.sqrt(c_1m**2 + (b_1m + (L_06m/2))**2) - np.sqrt(c_1m**2 + (b_1m - (L_06m/2))**2) ) / L_06m ))
theta_evaluation_3 = np.degrees(np.arcsin( (np.sqrt(c_4m**2 + (b_4m + (L_03m/2))**2) - np.sqrt(c_4m**2 + (b_4m - (L_03m/2))**2) ) / L_03m ))
theta_evaluation_4 = np.degrees(np.arcsin( (np.sqrt(c_4m**2 + (b_4m + (L_06m/2))**2) - np.sqrt(c_4m**2 + (b_4m - (L_06m/2))**2) ) / L_06m ))

plt.plot(theta_degrees, theta_evaluation_1, label=f'L = {L_03m}, AOmin = {AO_min_1m}', color='blue', linestyle='--')
plt.plot(theta_degrees, theta_evaluation_2, label=f'L = {L_06m}, AOmin = {AO_min_1m}', color='green', linestyle=':')
plt.plot(theta_degrees, theta_evaluation_3, label=f'L = {L_03m}, AOmax = {AO_max_4m}', color='red', linestyle='-')
plt.plot(theta_degrees, theta_evaluation_4, label=f'L = {L_06m}, AOmax = {AO_max_4m}', color='orange', linestyle='-.')

plt.xticks(np.arange(min(theta_degrees), max(theta_degrees)+1, 30))

plt.yticks(np.arange(-90, 100, 10))

plt.xlabel(r'$(\theta), град$')
plt.ylabel(r'$Оценка(\theta), град$')
plt.legend(loc='upper left', prop={'size': 10})
plt.grid(True)
plt.show()
